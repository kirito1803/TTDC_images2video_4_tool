# %%
import os
import subprocess
import time
import re

# %%
# !rm -rf /content/*

# %%
# !nvidia-smi
# Out:
# Tue Mar 31 02:27:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
print(os.getcwd())
# Out:
# /content

# %%
# %cd '/content'
# Out:
# /content

# %%
# !git clone https://github.com/kirito1803/TTDC_images2video_4_tool.git
# Out:
# Cloning into 'TTDC_images2video_4_tool'...
# remote: Enumerating objects: 1616, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 1616 (delta 1), reused 9 (delta 0), pack-reused 1601 (from 1)
# Receiving objects: 100% (1616/1616), 100.25 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (139/139), done.

# %%
# %cd TTDC_images2video_4_tool/images2video_4_tool/ComfyUI
# Out:
# /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI

# %%
# !pip install -r requirements.txt
# !pip install gguf accelerate safetensors pyngrok

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128"

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# %%
# start cloudflared in background
proc = subprocess.Popen(
    ["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8188"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True
)

# wait a bit for URL
time.sleep(5)

public_url = None

# đọc log để lấy URL
for _ in range(50):
    line = proc.stdout.readline()
    print(line.strip())
    match = re.search(r"(https://[-a-zA-Z0-9]+\.trycloudflare\.com)", line)
    if match:
        public_url = match.group(1)
        break

print("\n🌍 PUBLIC URL:", public_url)
# Out:
# 2026-03-31T02:28:16Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-03-31T02:28:16Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-03-31T02:28:21Z INF +--------------------------------------------------------------------------------------------+
# 2026-03-31T02:28:21Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %%
print(os.getcwd())
# Out:
# /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI

# %%
base = "models"

folders = [
    "audio_encoders",
    "checkpoints",
    "clip",
    "clip_vision",
    "configs",
    "controlnet",
    "diffusers",
    "diffusion_models",
    "embeddings",
    "gligen",
    "hypernetworks",
    "latent_upscale_models",
    "loras",
    "model_patches",
    "photomaker",
    "style_models",
    "text_encoders",
    "unet",
    "upscale_models",
    "vae",
    "vae_approx"
]

for f in folders:
    path = os.path.join(base, f)
    os.makedirs(path, exist_ok=True)

print("✅ Models folder structure created!")
# Out:
# ✅ Models folder structure created!

# %%
# !apt-get install -y aria2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,513 kB in 2s (659 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o qwen_image_edit_2509_fp8_e4m3fn.safetensors \
-d models/diffusion_models \
"https://huggingface.co/theunlikely/Qwen-Image-Edit-2509/resolve/main/qwen_image_edit_2509_fp8_e4m3fn.safetensors"
# Out:
# 03/31 02:28:31 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o Qwen-Image-Edit-Lightning-4steps-V1.0-bf16.safetensors \
-d models/loras \
"https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Edit-Lightning-4steps-V1.0-bf16.safetensors"
# Out:
# 03/31 02:30:27 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o Qwen-Edit-2509-Multiple-angles.safetensors \
-d models/loras \
"https://huggingface.co/Comfy-Org/Qwen-Image-Edit_ComfyUI/resolve/main/split_files/loras/Qwen-Edit-2509-Multiple-angles.safetensors"
# Out:
# 03/31 02:30:34 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o qwen_2.5_vl_7b_fp8_scaled.safetensors \
-d models/text_encoders \
"https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/text_encoders/qwen_2.5_vl_7b_fp8_scaled.safetensors"
# Out:
# 03/31 02:30:36 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o qwen_image_vae.safetensors \
-d models/vae \
"https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/vae/qwen_image_vae.safetensors"
# Out:
# 03/31 02:31:29 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o Wan2.2-I2V-A14B-HighNoise-Q5_K_S.safetensors \
-d models/loras \
"https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/HighNoise/Wan2.2-I2V-A14B-HighNoise-Q5_K_S.gguf"
# Out:
# 03/31 02:31:30 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o Wan2.2-I2V-A14B-LowNoise-Q5_K_M.safetensors \
-d models/loras \
"https://huggingface.co/QuantStack/Wan2.2-I2V-A14B-GGUF/resolve/main/LowNoise/Wan2.2-I2V-A14B-LowNoise-Q5_K_M.gguf"
# Out:
# 03/31 02:32:26 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o lightx2v_I2V_14B_480p_cfg_step_distill_rank64_bf16.safetensors \
-d models/loras \
"https://huggingface.co/Kijai/WanVideo_comfy/resolve/main/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank64_bf16.safetensors"
# Out:
# 03/31 02:33:43 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o clip_vision_h.safetensors \
-d models/clip_vision/ \
"https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/clip_vision/clip_vision_h.safetensors"
# Out:
# 03/31 02:33:47 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !aria2c -x 16 -s 16 -k 1M \
-o  wan_2.1_vae.safetensors\
-d models/vae \
"https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors"
# Out:
# 03/31 02:33:58 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !pip install torchlanc

# %%
# %cd custom_nodes

print(os.getcwd())
# Out:
# /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/custom_nodes
# /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/custom_nodes

# %%
# !git clone https://github.com/comfyroll/ComfyUI_Comfyroll_CustomNodes.git
# !git clone https://github.com/FizzleDorf/ComfyUI_FizzNodes.git
# Out:
# Cloning into 'ComfyUI_Comfyroll_CustomNodes'...
# fatal: could not read Username for 'https://github.com': No such device or address
# Cloning into 'ComfyUI_FizzNodes'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 646 (delta 170), reused 159 (delta 159), pack-reused 449 (from 3)
# Receiving objects: 100% (646/646), 184.47 KiB | 16.77 MiB/s, done.
# Resolving deltas: 100% (400/400), done.

# %%
# !apt-get install tree -y
# !tree -L 10 /content
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tree is already the newest version (2.0.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /content
# └── TTDC_images2video_4_tool
#     └── images2video_4_tool
#         ├── ComfyUI
#         │   ├── alembic_db
#         │   │   ├── env.py
#         │   │   ├── README.md
#         │   │   ├── script.py.mako
#         │   │   └── versions
#         │   │       ├── 0001_assets.py
#         │   │       ├── 0002_merge_to_asset_references.py
#         │   │       └── 0003_add_metadata_job_id.py
#         │   ├── alembic.ini
#         │   ├── api_server
#         │   │   ├── __init__.py
#         │   │   ├── routes
#         │   │   │   ├── __init__.py
#         │   │   │   └── internal
#         │   │   │       ├── __init__.py
#         │   │   │       ├── internal_routes.py
#         │   │   │       └── README.md
#         │   │   ├── services
# ...

# %%
# %cd ../

# !python main.py --listen 0.0.0.0 --port 8188
# Out:
# /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-03-31 02:38:02.913
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI
# ** ComfyUI Base Folder Path: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI
# ** User directory: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/user
# ** ComfyUI-Manager config path: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/user/__manager/config.ini
# ** Log path: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/user/comfyui.log
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/TTDC_images2video_4_tool/images2video_4_tool/ComfyUI/custom_nodes/rgthree-comfy
# ...
